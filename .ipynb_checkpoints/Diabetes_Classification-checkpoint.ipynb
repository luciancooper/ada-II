# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyhtml import display
from pybook import reload
import pygraph
import pydec
import pyml
import pygraph
#plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ### `Fields`
# * **`Pregnancies`** - `Numeric` - Number of times pregnant
# * **`Glucose`** - `Numeric` - Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * **`BloodPressure`** - `Numeric` - Diastolic blood pressure (mm Hg)
# * **`SkinThickness`** - `Numeric` - Triceps skin fold thickness (mm)
# * **`Insulin`** - `Numeric` - 2-Hour serum insulin (mu U/ml)
# * **`BMI`** - `Numeric` - Body mass index (weight in kg/(height in m)^2)
# * **`DiabetesPedigreeFunction`** - `Numeric` - Diabetes pedigree function
# * **`Age`** - `Numeric` - Age (years)
# * **`Outcome`** - `Numeric` - Class variable (0 or 1)

# %%
diabetes = pd.read_csv("datafiles/diabetes.csv").rename(columns={'DiabetesPedigreeFunction':'DPF','BloodPressure':'BP','SkinThickness':'SkinThck'})
display(diabetes,'diabetes data')
# Out:
# <section id='LC-YKPPXTKVSX'><style>#LC-YKPPXTKVSX {font-family: monospace;/*font-size:12px;*/max-height:400px!important;overflow:scroll;padding:5px;background:transparent;}#LC-YKPPXTKVSX div {border:1px solid transparent!important;background:transparent;margin:5px;}#LC-YKPPXTKVSX section {display:flex;flex-flow:row nowrap;align-items:flex-start;justify-content:flex-start;border:0px;padding:0px;}#LC-YKPPXTKVSX h3,#LC-YKPPXTKVSX h4,#LC-YKPPXTKVSX h5 {padding:1px;}#LC-YKPPXTKVSX h3,#LC-YKPPXTKVSX h4 {font-weight:bold;}#LC-YKPPXTKVSX h4,#LC-YKPPXTKVSX h5 {margin:0px 0px 4px 0px;    text-align:left;}#LC-YKPPXTKVSX h3 {margin:1px;text-align:center;}#LC-YKPPXTKVSX h5 {color:#5D5D5D;font-style:normal;font-weight:normal;}#LC-YKPPXTKVSX table {color: #3E4349;/*font: normal normal normal 12px/10px "Courier New", monospace!important;*/border-spacing:1px!important;    border-collapse:collapse!important;font-size: 0.9em;font-family:monospace;border-style:solid;border-color:grey;border-width:0px;margin:1px;/*background: #FFF;    table-layout: fixed;*/}#LC-YKPPXTKVSX table thead,#LC-YKPPXTKVSX table tbody,#LC-YKPPXTKVSX table tfoot,#LC-YKPPXTKVSX table tr {border-color: inherit;border-style:inherit;border-width:0px;}#LC-YKPPXTKVSX table thead {vertical-align: bottom;border-bottom-width:1px;}#LC-YKPPXTKVSX table tbody {    display: table-row-group;    vertical-align: middle;overflow:scroll!important;background:transparent!important;}#LC-YKPPXTKVSX table tfoot {border-top-width:2px;border-top-color:black;}#LC-YKPPXTKVSX table tr {    vertical-align: middle;    padding: 1px 0.5em;    line-height: normal;    white-space:pre!important;    max-width: none;background:transparent!important;}#LC-YKPPXTKVSX table th,#LC-YKPPXTKVSX table td {padding: 1px 0.5em;white-space:pre!important;max-width: none;line-height: normal;min-width:3px;border-width:1px;border-style:inherit;border-color:inherit;vertical-align:middle;font-family: inherit;}#LC-YKPPXTKVSX table td {text-align: right;}#LC-YKPPXTKVSX table th:empty,#LC-YKPPXTKVSX table td:empty {visibility: hidden;}#LC-YKPPXTKVSX table tbody+tbody:before {content:'...';display:table-row;line-height:10px;text-align:center;}#LC-YKPPXTKVSX table td.row-sep {visibility:visible;border:none;}#LC-YKPPXTKVSX table td.row-sep:before {content:'...';}#LC-YKPPXTKVSX table tbody tr,#LC-YKPPXTKVSX table tbody tr:hover,#LC-YKPPXTKVSX table tbody tr:hover>*{    background: #FFF!important;}#LC-YKPPXTKVSX table tr>th:last-of-type {border-right-color:black;}#LC-YKPPXTKVSX table th {text-align: right;font-weight: bold;}#LC-YKPPXTKVSX table thead th,#LC-YKPPXTKVSX table thead td {    text-align: center;    color:#FFF;    text-shadow:1px 1px rgba(0,0,0,1),0px 1px rgba(0,0,0,1),1px 0px rgba(0,0,0,1),-0.5px -0.5px rgba(0,0,0,1);}#LC-YKPPXTKVSX table tbody td.grey {background:#EBE8ED;}#LC-YKPPXTKVSX table tbody td.light-grey {background:#f3f1f4;}#LC-YKPPXTKVSX table tbody th {background:#E1F5FE;}#LC-YKPPXTKVSX table thead th {background:#95d1ff;}#LC-YKPPXTKVSX table thead td {    background:#33a7ff;}#LC-YKPPXTKVSX table tfoot td {    background:#F5F5F5;}#LC-YKPPXTKVSX table tfoot th {    background:#d9d9d9;}#LC-YKPPXTKVSX table.arrpy tbody th {background:#D8BFD8;}#LC-YKPPXTKVSX table.arrpy thead th {background:#EE82EE;}#LC-YKPPXTKVSX table.arrpy thead td {    background:#DA70D6;}#LC-YKPPXTKVSX table.pandas tbody th {background:#E1F5FE;}#LC-YKPPXTKVSX table.pandas thead th {background:#95d1ff;}#LC-YKPPXTKVSX table.pandas thead td {    background:#33a7ff;}#LC-YKPPXTKVSX table.numpy tbody th {background:#EEEEFE;}#LC-YKPPXTKVSX table.numpy tr>th:last-of-type {border-right-color:grey;margin-right:3px;}</style><div><
th><td>0</td></tr>
# </tbody><tfoot><tr><th colspan="1">object</th><td>int</td></tr></tfoot></table></div></section></section>

# %% [markdown]
# # `Visualize Feature Distributions`

# %%
diabetes[['Age','BMI','BP','DPF','Glucose','Insulin','Pregnancies','SkinThck']].hist(bins=50,figsize=(16,12),color='b',edgecolor='black',histtype='bar')
plt.tight_layout()
plt.show()

# %%
reload(pygraph)
pygraph.piechart(diabetes['Outcome'],shadow=True,colors=['g','r'],show=True)

# %%
reload(pygraph)
pygraph.histogram(diabetes['BMI'],size=(5,3),show=True,bins=40)

# %%
def zero_features(feature):
    return feature[feature==0]

display(dict((x,zero_features(diabetes[x])) for x in ['BP','Glucose','SkinThck','BMI','Insulin']))
# Out:
# <section id='LC-YZ00JGCR7H'><style>#LC-YZ00JGCR7H {font-family: monospace;/*font-size:12px;*/max-height:400px!important;overflow:scroll;padding:5px;background:transparent;}#LC-YZ00JGCR7H div {border:1px solid transparent!important;background:transparent;margin:5px;}#LC-YZ00JGCR7H section {display:flex;flex-flow:row nowrap;align-items:flex-start;justify-content:flex-start;border:0px;padding:0px;}#LC-YZ00JGCR7H h3,#LC-YZ00JGCR7H h4,#LC-YZ00JGCR7H h5 {padding:1px;}#LC-YZ00JGCR7H h3,#LC-YZ00JGCR7H h4 {font-weight:bold;}#LC-YZ00JGCR7H h4,#LC-YZ00JGCR7H h5 {margin:0px 0px 4px 0px;    text-align:left;}#LC-YZ00JGCR7H h3 {margin:1px;text-align:center;}#LC-YZ00JGCR7H h5 {color:#5D5D5D;font-style:normal;font-weight:normal;}#LC-YZ00JGCR7H table {color: #3E4349;/*font: normal normal normal 12px/10px "Courier New", monospace!important;*/border-spacing:1px!important;    border-collapse:collapse!important;font-size: 0.9em;font-family:monospace;border-style:solid;border-color:grey;border-width:0px;margin:1px;/*background: #FFF;    table-layout: fixed;*/}#LC-YZ00JGCR7H table thead,#LC-YZ00JGCR7H table tbody,#LC-YZ00JGCR7H table tfoot,#LC-YZ00JGCR7H table tr {border-color: inherit;border-style:inherit;border-width:0px;}#LC-YZ00JGCR7H table thead {vertical-align: bottom;border-bottom-width:1px;}#LC-YZ00JGCR7H table tbody {    display: table-row-group;    vertical-align: middle;overflow:scroll!important;background:transparent!important;}#LC-YZ00JGCR7H table tfoot {border-top-width:2px;border-top-color:black;}#LC-YZ00JGCR7H table tr {    vertical-align: middle;    padding: 1px 0.5em;    line-height: normal;    white-space:pre!important;    max-width: none;background:transparent!important;}#LC-YZ00JGCR7H table th,#LC-YZ00JGCR7H table td {padding: 1px 0.5em;white-space:pre!important;max-width: none;line-height: normal;min-width:3px;border-width:1px;border-style:inherit;border-color:inherit;vertical-align:middle;font-family: inherit;}#LC-YZ00JGCR7H table td {text-align: right;}#LC-YZ00JGCR7H table th:empty,#LC-YZ00JGCR7H table td:empty {visibility: hidden;}#LC-YZ00JGCR7H table tbody+tbody:before {content:'...';display:table-row;line-height:10px;text-align:center;}#LC-YZ00JGCR7H table td.row-sep {visibility:visible;border:none;}#LC-YZ00JGCR7H table td.row-sep:before {content:'...';}#LC-YZ00JGCR7H table tbody tr,#LC-YZ00JGCR7H table tbody tr:hover,#LC-YZ00JGCR7H table tbody tr:hover>*{    background: #FFF!important;}#LC-YZ00JGCR7H table tr>th:last-of-type {border-right-color:black;}#LC-YZ00JGCR7H table th {text-align: right;font-weight: bold;}#LC-YZ00JGCR7H table thead th,#LC-YZ00JGCR7H table thead td {    text-align: center;    color:#FFF;    text-shadow:1px 1px rgba(0,0,0,1),0px 1px rgba(0,0,0,1),1px 0px rgba(0,0,0,1),-0.5px -0.5px rgba(0,0,0,1);}#LC-YZ00JGCR7H table tbody td.grey {background:#EBE8ED;}#LC-YZ00JGCR7H table tbody td.light-grey {background:#f3f1f4;}#LC-YZ00JGCR7H table tbody th {background:#E1F5FE;}#LC-YZ00JGCR7H table thead th {background:#95d1ff;}#LC-YZ00JGCR7H table thead td {    background:#33a7ff;}#LC-YZ00JGCR7H table tfoot td {    background:#F5F5F5;}#LC-YZ00JGCR7H table tfoot th {    background:#d9d9d9;}#LC-YZ00JGCR7H table.arrpy tbody th {background:#D8BFD8;}#LC-YZ00JGCR7H table.arrpy thead th {background:#EE82EE;}#LC-YZ00JGCR7H table.arrpy thead td {    background:#DA70D6;}#LC-YZ00JGCR7H table.pandas tbody th {background:#E1F5FE;}#LC-YZ00JGCR7H table.pandas thead th {background:#95d1ff;}#LC-YZ00JGCR7H table.pandas thead td {    background:#33a7ff;}#LC-YZ00JGCR7H table.numpy tbody th {background:#EEEEFE;}#LC-YZ00JGCR7H table.numpy tr>th:last-of-type {border-right-color:grey;margin-right:3px;}</style><section><div><h4>BP</h4><h5>Series[35]</h5><table class='pandas series'><thead><tr><th></th><th>BP</th></tr>
# </thead><tbody><tr><th>7</th><td>0</td></tr>
# <tr><th>15</th><td>0</td></tr>
# <tr><th>49</th><td>0</td></tr>
# <tr><th>60</th><td>0</td></tr>
# <tr><th>78</th><td>0</td></tr>
# </tbody><tbody><tr><th>619</th><td>0</td></tr>
# <tr><th>643</th><td>0</td></tr>
# <tr><th>697</th><td>0</td></tr>
# <tr><th>703</th><td>0</td></tr>
# <tr><th>706</th><td>0</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>int</td></tr></tfoot></table></div><div><h4>Glucose</h4><h5>Series[5]</h5><table class='pandas series'><thead><tr><th></th><th>Glucose</th></tr>
# </thead><tbody><tr><th>75</th><td>0</td></tr>
# <tr><th>182</th><td>0</td></tr>
# <tr><th>342</th><td>0</td></tr>
# <tr><th>349</th><td>0</td></tr>
# <tr><th>502</th><td>0</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>int</td></tr></tfoot></table></div><div><h4>SkinThck</h4><h5>Series[227]</h5><table class='pandas series'><thead><tr><th></th><th>SkinThck</th></tr>
# </thead><tbody><tr><th>2</th><td>0</td></tr>
# <tr><th>5</th><td>0</td></tr>
# <tr><th>7</th><td>0</td></tr>
# <tr><th>9</th><td>0</td></tr>
# <tr><th>10</th><td>0</td></tr>
# </tbody><tbody><tr><th>757</th><td>0</td></tr>
# <tr><th>758</th><td>0</td></tr>
# <tr><th>759</th><td>0</td></tr>
# <tr><th>762</th><td>0</td></tr>
# <tr><th>766</th><td>0</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>int</td></tr></tfoot></table></div><div><h4>BMI</h4><h5>Series[11]</h5><table class='pandas series'><thead><tr><th></th><th>BMI</th></tr>
# </thead><tbody><tr><th>9</th><td>0.000</td></tr>
# <tr><th>49</th><td>0.000</td></tr>
# <tr><th>60</th><td>0.000</td></tr>
# <tr><th>81</th><td>0.000</td></tr>
# <tr><th>145</th><td>0.000</td></tr>
# </tbody><tbody><tr><th>426</th><td>0.000</td></tr>
# <tr><th>494</th><td>0.000</td></tr>
# <tr><th>522</th><td>0.000</td></tr>
# <tr><th>684</th><td>0.000</td></tr>
# <tr><th>706</th><td>0.000</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>float</td></tr></tfoot></table></div><div><h4>Insulin</h4><h5>Series[374]</h5><table class='pandas series'><thead><tr><th></th><th>Insulin</th></tr>
# </thead><tbody><tr><th>0</th><td>0</td></tr>
# <tr><th>1</th><td>0</td></tr>
# <tr><th>2</th><td>0</td></tr>
# <tr><th>5</th><td>0</td></tr>
# <tr><th>7</th><td>0</td></tr>
# </tbody><tbody><tr><th>761</th><td>0</td></tr>
# <tr><th>762</th><td>0</td></tr>
# <tr><th>764</th><td>0</td></tr>
# <tr><th>766</th><td>0</td></tr>
# <tr><th>767</th><td>0</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>int</td></tr></tfoot></table></div></section></section>

# %%
train_set,test_set = pyml.split_stratified(diabetes,diabetes['Outcome'],0.2,seed=42)
print('train [%i] test[%i]'%(len(train_set),len(test_set)))
# Out:
# train [614] test[154]

# %% [markdown]
# # `Explore Feature Correlations`

# %%
corr_matrix = train_set.corr()
display(corr_matrix)
# Out:
# <section id='LC-FUSMHVYNV8'><style>#LC-FUSMHVYNV8 {font-family: monospace;/*font-size:12px;*/max-height:400px!important;overflow:scroll;padding:5px;background:transparent;}#LC
# <tr><th>BP</th><td>0.100</td><td>0.148</td><td>1.000</td><td>0.156</td><td>0.087</td><td>0.270</td><td>0.023</td><td>0.216</td><td>0.082</td></tr>
# <tr><th>SkinThck</th><td>-0.121</td><td>0.051</td><td>0.156</td><td>1.000</td><td>0.472</td><td>0.374</td><td>0.195</td><td>-0.115</td><td>0.094</td></tr>
# <tr><th>Insulin</th><td>-0.060</td><td>0.350</td><td>0.087</td><td>0.472</td><td>1.000</td><td>0.204</td><td>0.239</td><td>-0.031</td><td>0.164</td></tr>
# <tr><th>BMI</th><td>0.004</td><td>0.199</td><td>0.270</td><td>0.374</td><td>0.204</td><td>1.000</td><td>0.138</td><td>0.030</td><td>0.301</td></tr>
# <tr><th>DPF</th><td>-0.052</td><td>0.135</td><td>0.023</td><td>0.195</td><td>0.239</td><td>0.138</td><td>1.000</td><td>0.025</td><td>0.165</td></tr>
# <tr><th>Age</th><td>0.536</td><td>0.282</td><td>0.216</td><td>-0.115</td><td>-0.031</td><td>0.030</td><td>0.025</td><td>1.000</td><td>0.241</td></tr>
# <tr><th>Outcome</th><td>0.208</td><td>0.479</td><td>0.082</td><td>0.094</td><td>0.164</td><td>0.301</td><td>0.165</td><td>0.241</td><td>1.000</td></tr>
# </tbody><tfoot><tr><th colspan="1">object</th><td>float</td><td>float</td><td>float</td><td>float</td><td>float</td><td>float</td><td>float</td><td>float</td><td>float</td></tr></tfoot></table></div></section>

# %%
pygraph.scatterplot_matrix(train_set[['DPF','BMI','Glucose','BP','SkinThck','Insulin','Age']])
plt.show()

# %%
reload(pygraph)
pygraph.scatterplot_matrix(train_set)
plt.show()

# %%
fig = plt.figure(facecolor='lightgrey')
grid = plt.GridSpec(3, 6,wspace=0.4,hspace=0.3)
g = grid[0,0:2]
print(type(g))
print(g.get_geometry())
print(g.get_gridspec())
print(g.get_position(fig))
print(g.get_topmost_subplotspec())
fig.add_axes(g.get_position(fig))
plt.show()
# Out:
# <class 'matplotlib.gridspec.SubplotSpec'>
# (3, 6, 0, 1)
# <matplotlib.gridspec.GridSpec object at 0x1a1e1e9c88>
# Bbox(x0=0.125, y0=0.6702777777777778, x1=0.3575, y1=0.88)
# <matplotlib.gridspec.SubplotSpec object at 0x1a1e2f3a20>

# %%
fig = plt.figure(facecolor='lightgrey')
grid = plt.GridSpec(3, 6)
subplt = [grid[0,0:2],grid[0,2:4],grid[0,4:6],grid[1,0:2],grid[1,2:4],grid[1,4:6],grid[2,1:3],grid[2,3:5]]
#ax = list(fig.add_axes(x.get_position(fig)) for x in subplt)
ax = list(fig.add_subplot(x,xticklabels=[],yticklabels=[]) for x in subplt)

#fig.subplots_adjust(hspace=0.4, wspace=0.4)
#ax1 = fig.add_axes([0.0, 0.0, 1.0, 0.50],xticklabels=[],yticklabels=[])
#print(type(ax1))
#ax2 = fig.add_axes([0.0, 0.53, 1.0, 0.50],xticklabels=[],yticklabels=[])
plt.tight_layout()
plt.show()

# %%
reload(pygraph)
pygraph.histogram(diabetes['BMI'],size=(5,3),show=True,bins=40)

# %%
reload(pygraph)
pygraph.histogram(diabetes[['Age','BMI','BP','DPF','Glucose','Insulin','Pregnancies','SkinThck']],size=(4,3),show=True,bins=40,alpha=0.5,edgecolor='black')
