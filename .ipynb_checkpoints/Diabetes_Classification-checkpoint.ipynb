# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyhtml import display
from pybook import reload
import pygraph
import pydec
import pyml
import pygraph
#plt.style.use('seaborn-whitegrid')

# %%
reload(pygraph)

# %% [markdown]
# ### `Fields`
# * **`Pregnancies`** - `Numeric` - Number of times pregnant
# * **`Glucose`** - `Numeric` - Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * **`BloodPressure`** - `Numeric` - Diastolic blood pressure (mm Hg)
# * **`SkinThickness`** - `Numeric` - Triceps skin fold thickness (mm)
# * **`Insulin`** - `Numeric` - 2-Hour serum insulin (mu U/ml)
# * **`BMI`** - `Numeric` - Body mass index (weight in kg/(height in m)^2)
# * **`DiabetesPedigreeFunction`** - `Numeric` - Diabetes pedigree function
# * **`Age`** - `Numeric` - Age (years)
# * **`Outcome`** - `Numeric` - Class variable (0 or 1)

# %%
diabetes = pd.read_csv("datafiles/diabetes.csv").rename(columns={'DiabetesPedigreeFunction':'DPF','BloodPressure':'BP','SkinThickness':'SkinThck'})
display(diabetes,'diabetes data')
# Out:
# <section id='LC-UC7M4YHCTB'><style>#LC-UC7M4YHCTB {font-family: monospace;/*font-size:12px;*/max-height:400px!important;overflow:scroll;padding:5px;background:transparent;}#LC-UC7M4YHCTB div {border:1px solid transparent!important;background:transparent;margin:5px;}#LC-UC7M4YHCTB section {display:flex;flex-flow:row nowrap;align-items:flex-start;justify-content:flex-start;border:0px;padding:0px;}#LC-UC7M4YHCTB h3,#LC-UC7M4YHCTB h4,#LC-UC7M4YHCTB h5 {padding:1px;}#LC-UC7M4YHCTB h3,#LC-UC7M4YHCTB h4 {font-weight:bold;}#LC-UC7M4YHCTB h4,#LC-UC7M4YHCTB h5 {margin:0px 0px 4px 0px;    text-align:left;}#LC-UC7M4YHCTB h3 {margin:1px;text-align:center;}#LC-UC7M4YHCTB h5 {color:#5D5D5D;font-style:normal;font-weight:normal;}#LC-UC7M4YHCTB table {color: #3E4349;/*font: normal normal normal 12px/10px "Courier New", monospace!important;*/border-spacing:1px!important;    border-collapse:collapse!important;font-size: 0.9em;font-family:monospace;border-style:solid;border-color:grey;border-width:0px;margin:1px;/*background: #FFF;    table-layout: fixed;*/}#LC-UC7M4YHCTB table thead,#LC-UC7M4YHCTB table tbody,#LC-UC7M4YHCTB table tfoot,#LC-UC7M4YHCTB table tr {border-color: inherit;border-style:inherit;border-width:0px;}#LC-UC7M4YHCTB table thead {vertical-align: bottom;border-bottom-width:1px;}#LC-UC7M4YHCTB table tbody {    display: table-row-group;    vertical-align: middle;overflow:scroll!important;background:transparent!important;}#LC-UC7M4YHCTB table tfoot {border-top-width:2px;border-top-color:black;}#LC-UC7M4YHCTB table tr {    vertical-align: middle;    padding: 1px 0.5em;    line-height: normal;    white-space:pre!important;    max-width: none;background:transparent!important;}#LC-UC7M4YHCTB table th,#LC-UC7M4YHCTB table td {padding: 1px 0.5em;white-space:pre!important;max-width: none;line-height: normal;min-width:3px;border-width:1px;border-style:inherit;border-color:inherit;vertical-align:middle;font-family: inherit;}#LC-UC7M4YHCTB table td {text-align: right;}#LC-UC7M4YHCTB table th:empty,#LC-UC7M4YHCTB table td:empty {visibility: hidden;}#LC-UC7M4YHCTB table tbody+tbody:before {content:'...';display:table-row;line-height:10px;text-align:center;}#LC-UC7M4YHCTB table td.row-sep {visibility:visible;border:none;}#LC-UC7M4YHCTB table td.row-sep:before {content:'...';}#LC-UC7M4YHCTB table tbody tr,#LC-UC7M4YHCTB table tbody tr:hover,#LC-UC7M4YHCTB table tbody tr:hover>*{    background: #FFF!important;}#LC-UC7M4YHCTB table tr>th:last-of-type {border-right-color:black;}#LC-UC7M4YHCTB table th {text-align: right;font-weight: bold;}#LC-UC7M4YHCTB table thead th,#LC-UC7M4YHCTB table thead td {    text-align: center;    color:#FFF;    text-shadow:1px 1px rgba(0,0,0,1),0px 1px rgba(0,0,0,1),1px 0px rgba(0,0,0,1),-0.5px -0.5px rgba(0,0,0,1);}#LC-UC7M4YHCTB table tbody td.grey {background:#EBE8ED;}#LC-UC7M4YHCTB table tbody td.light-grey {background:#f3f1f4;}#LC-UC7M4YHCTB table tbody th {background:#E1F5FE;}#LC-UC7M4YHCTB table thead th {background:#95d1ff;}#LC-UC7M4YHCTB table thead td {    background:#33a7ff;}#LC-UC7M4YHCTB table tfoot td {    background:#F5F5F5;}#LC-UC7M4YHCTB table tfoot th {    background:#d9d9d9;}#LC-UC7M4YHCTB table.arrpy tbody th {
.numpy tr>th:last-of-type {border-right-color:grey;margin-right:3px;}</style><section><div><h4>features</h4><h5>DataFrame[768 x 8]</h5><table class='pandas dataframe'><thead><tr><th></th><td>Pregnancies</td><td>Glucose</td><td>BP</td><td>SkinThck</td><td>Insulin</td><td>BMI</td><td>DPF</td><td>Age</td></tr>
# </thead><tbody><tr><th>0</th><td>6</td><td>148</td><td>72</td><td>35</td><td>0</td><td>33.600</td><td>0.627</td><td>50</td></tr>
# <tr><th>1</th><td>1</td><td>85</td><td>66</td><td>29</td><td>0</td><td>26.600</td><td>0.351</td><td>31</td></tr>
# <tr><th>2</th><td>8</td><td>183</td><td>64</td><td>0</td><td>0</td><td>23.300</td><td>0.672</td><td>32</td></tr>
# <tr><th>3</th><td>1</td><td>89</td><td>66</td><td>23</td><td>94</td><td>28.100</td><td>0.167</td><td>21</td></tr>
# <tr><th>4</th><td>0</td><td>137</td><td>40</td><td>35</td><td>168</td><td>43.100</td><td>2.288</td><td>33</td></tr>
# </tbody><tbody><tr><th>763</th><td>10</td><td>101</td><td>76</td><td>48</td><td>180</td><td>32.900</td><td>0.171</td><td>63</td></tr>
# <tr><th>764</th><td>2</td><td>122</td><td>70</td><td>27</td><td>0</td><td>36.800</td><td>0.340</td><td>27</td></tr>
# <tr><th>765</th><td>5</td><td>121</td><td>72</td><td>23</td><td>112</td><td>26.200</td><td>0.245</td><td>30</td></tr>
# <tr><th>766</th><td>1</td><td>126</td><td>60</td><td>0</td><td>0</td><td>30.100</td><td>0.349</td><td>47</td></tr>
# <tr><th>767</th><td>1</td><td>93</td><td>70</td><td>31</td><td>0</td><td>30.400</td><td>0.315</td><td>23</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>int</td><td>int</td><td>int</td><td>int</td><td>int</td><td>float</td><td>float</td><td>int</td></tr></tfoot></table></div><div><h4>labels</h4><h5>Series[768]</h5><table class='pandas series'><thead><tr><th></th><th>Outcome</th></tr>
# </thead><tbody><tr><th>0</th><td>1</td></tr>
# <tr><th>1</th><td>0</td></tr>
# <tr><th>2</th><td>1</td></tr>
# <tr><th>3</th><td>0</td></tr>
# <tr><th>4</th><td>1</td></tr>
# </tbody><tbody><tr><th>763</th><td>0</td></tr>
# <tr><th>764</th><td>0</td></tr>
# <tr><th>765</th><td>0</td></tr>
# <tr><th>766</th><td>1</td></tr>
# <tr><th>767</th><td>0</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>int</td></tr></tfoot></table></div></section></section>

# %% [markdown]
# # `Visualize Label Value Distribution`

# %%
pygraph.piechart(labels,shadow=True,colors=['g','r'],show=True)

# %% [markdown]
# # `Visualize Feature Distributions`

# %%
#features.hist(bins=50,figsize=(16,12),color='b',edgecolor='black',histtype='bar')
#plt.tight_layout()
#plt.show()

#pygraph.histogram(diabetes['BMI'],size=(5,3),show=True,bins=40)
pygraph.histogram(features,size=(4,3),show=True,bins=40,alpha=0.5,edgecolor='black')

# %%
def zero_features(feature):
    return feature[feature==0]

display(dict((x,zero_features(diabetes[x])) for x in ['BP','Glucose','SkinThck','BMI','Insulin']))
# Out:
# <section id='LC-2S5UULUAET'><style>#LC-2S5UULUAET {font-family: monospace;/*font-size:12px;*/max-height:400px!important;overflow:scroll;padding:5px;background:transparent;}#LC-2S5UULUAET div {border:1px solid transparent!important;background:transparent;margin:5px;}#LC-2S5UULUAET section {display:flex;flex-flow:row nowrap;align-items:flex-start;justify-content:flex-start;border:0px;padding:0px;}#LC-2S5UULUAET h3,#LC-2S5UULUAET h4,#LC-2S5UULUAET h5 {padding:1px;}#LC-2S5UULUAET h3,#LC-2S5UULUAET h4 {font-weight:bold;}#LC-2S5UULUAET h4,#LC-2S5UULUAET h5 {margin:0px 0px 4px 0px;    text-align:left;}#LC-2S5UULUAET h3 {margin:1px;text-align:center;}#LC-2S5UULUAET h5 {color:#5D5D5D;font-style:normal;font-weight:normal;}#LC-2S5UULUAET table {color: #3E4349;/*font: normal normal normal 12px/10px "Courier New", monospace!important;*/border-spacing:1px!important;    border-collapse:collapse!important;font-size: 0.9em;font-family:monospace;border-style:solid;border-color:grey;border-width:0px;margin:1px;/*background: #FFF;    table-layout: fixed;*/}#LC-2S5UULUAET table thead,#LC-2S5UULUAET table tbody,#LC-2S5UULUAET table tfoot,#LC-2S5UULUAET table tr {border-color: inherit;border-style:inherit;border-width:0px;}#LC-2S5UULUAET table thead {vertical-align: bottom;border-bottom-width:1px;}#LC-2S5UULUAET table tbody {    display: table-row-group;    vertical-align: middle;overflow:scroll!important;background:transparent!important;}#LC-2S5UULUAET table tfoot {border-top-width:2px;border-top-color:black;}#LC-2S5UULUAET table tr {    vertical-align: middle;    padding: 1px 0.5em;    line-height: normal;    white-space:pre!important;    max-width: none;background:transparent!important;}#LC-2S5UULUAET table th,#LC-2S5UULUAET table td {padding: 1px 0.5em;white-space:pre!important;max-width: none;line-height: normal;min-width:3px;border-width:1px;border-style:inherit;border-color:inherit;vertical-align:middle;font-family: inherit;}#LC-2S5UULUAET table td {text-align: right;}#LC-2S5UULUAET table th:empty,#LC-2S5UULUAET table td:empty {visibility: hidden;}#LC-2S5UULUAET table tbody+tbody:before {content:'...';display:table-row;line-height:10px;text-align:center;}#LC-2S5UULUAET table td.row-sep {visibility:visible;border:none;}#LC-2S5UULUAET table td.row-sep:before {content:'...';}#LC-2S5UULUAET table tbody tr,#LC-2S5UULUAET table tbody tr:hover,#LC-2S5UULUAET table tbody tr:hover>*{    background: #FFF!important;}#LC-2S5UULUAET table tr>th:last-of-type {border-right-color:black;}#LC-2S5UULUAET table th {text-align: right;font-weight: bold;}#LC-2S5UULUAET table thead th,#LC-2S5UULUAET table thead td {    text-align: center;    color:#FFF;    text-shadow:1px 1px rgba(0,0,0,1),0px 1px rgba(0,0,0,1),1px 0px rgba(0,0,0,1),-0.5px -0.5px rgba(0,0,0,1);}#LC-2S5UULUAET table tbody td.grey {background:#EBE8ED;}#LC-2S5UULUAET table tbody td.light-grey {background:#f3f1f4;}#LC-2S5UULUAET table tbody th {background:#E1F5FE;}#LC-2S5UULUAET table thead th {background:#95d1ff;}#LC-2S5UULUAET table thead td {    background:#33a7ff;}#LC-2S5UULUAET table tfoot td {    background:#F5F5F5;}#LC-2S5UULUAET table tfoot th {    background:#d9d9d9;}#LC-2S5UULUAET table.arrpy tbody th {background:#D8BFD8;}#LC-2S5UULUAET table.arrpy thead th {background:#EE82EE;}#LC-2S5UULUAET table.arrpy thead td {    background:#DA70D6;}#LC-2S5UULUAET table.pandas tbody th {background:#E1F5FE;}#LC-2S5UULUAET table.pandas thead th {background:#95d1ff;}#LC-2S5UULUAET table.pandas thead td {    background:#33a7ff;}#LC-2S5UULUAET table.numpy tbody th {background:#EEEEFE;}#LC-2S5UULUAET table.numpy tr>th:last-of-type {border-right-color:grey;margin-right:3px;}</style><section><div><h4>BP</h4><h5>Series[35]</h5><table class='pandas series'><thead><tr><th></th><th>BP</th></tr>
# </thead><tbody><tr><th>7</th><td>0</td></tr>
# <tr><th>15</th><td>0</td></tr>
# <tr><th>49</th><td>0</td></tr>
# <tr><th>60</th><td>0</td></tr>
# <tr><th>78</th><td>0</td></tr>
# </tbody><tbody><tr><th>619</th><td>0</td></tr>
# <tr><th>643</th><td>0</td></tr>
# <tr><th>697</th><td>0</td></tr>
# <tr><th>703</th><td>0</td></tr>
# <tr><th>706</th><td>0</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>int</td></tr></tfoot></table></div><div><h4>Glucose</h4><h5>Series[5]</h5><table class='pandas series'><thead><tr><th></th><th>Glucose</th></tr>
# </thead><tbody><tr><th>75</th><td>0</td></tr>
# <tr><th>182</th><td>0</td></tr>
# <tr><th>342</th><td>0</td></tr>
# <tr><th>349</th><td>0</td></tr>
# <tr><th>502</th><td>0</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>int</td></tr></tfoot></table></div><div><h4>SkinThck</h4><h5>Series[227]</h5><table class='pandas series'><thead><tr><th></th><th>SkinThck</th></tr>
# </thead><tbody><tr><th>2</th><td>0</td></tr>
# <tr><th>5</th><td>0</td></tr>
# <tr><th>7</th><td>0</td></tr>
# <tr><th>9</th><td>0</td></tr>
# <tr><th>10</th><td>0</td></tr>
# </tbody><tbody><tr><th>757</th><td>0</td></tr>
# <tr><th>758</th><td>0</td></tr>
# <tr><th>759</th><td>0</td></tr>
# <tr><th>762</th><td>0</td></tr>
# <tr><th>766</th><td>0</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>int</td></tr></tfoot></table></div><div><h4>BMI</h4><h5>Series[11]</h5><table class='pandas series'><thead><tr><th></th><th>BMI</th></tr>
# </thead><tbody><tr><th>9</th><td>0.000</td></tr>
# <tr><th>49</th><td>0.000</td></tr>
# <tr><th>60</th><td>0.000</td></tr>
# <tr><th>81</th><td>0.000</td></tr>
# <tr><th>145</th><td>0.000</td></tr>
# </tbody><tbody><tr><th>426</th><td>0.000</td></tr>
# <tr><th>494</th><td>0.000</td></tr>
# <tr><th>522</th><td>0.000</td></tr>
# <tr><th>684</th><td>0.000</td></tr>
# <tr><th>706</th><td>0.000</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>float</td></tr></tfoot></table></div><div><h4>Insulin</h4><h5>Series[374]</h5><table class='pandas series'><thead><tr><th></th><th>Insulin</th></tr>
# </thead><tbody><tr><th>0</th><td>0</td></tr>
# <tr><th>1</th><td>0</td></tr>
# <tr><th>2</th><td>0</td></tr>
# <tr><th>5</th><td>0</td></tr>
# <tr><th>7</th><td>0</td></tr>
# </tbody><tbody><tr><th>761</th><td>0</td></tr>
# <tr><th>762</th><td>0</td></tr>
# <tr><th>764</th><td>0</td></tr>
# <tr><th>766</th><td>0</td></tr>
# <tr><th>767</th><td>0</td></tr>
# </tbody><tfoot><tr><th colspan="1">int64</th><td>int</td></tr></tfoot></table></div></section></section>

# %% [markdown]
# # `Explore Feature Correlations`

# %%
corr_matrix = diabetes.corr()
display(corr_matrix)
# Out:
# <section id='LC-FGH2I8446F'><style>#LC-FGH2I8446F {font-family: monospace;/*font-size:12px;*/max-height:400px!important;overflow:scroll;padding:5px;background:transparent;}#LC-FGH2I8446F div {border:1px solid transparent!important;background:transparent;margin:5px;}#LC-FGH2I8446F section {display:flex;flex-flow:row nowrap;align-items:flex-start;justify-content:flex-start;border:0px;padding:0px;}#LC-FGH2I8446F h3,#LC-FGH2I8446F h4,#LC-FGH2I8446F h5 {padding:1px;}#LC-FGH2I8446F h3,#LC-FGH2I8446F h4 {font-weight:bold;}#LC-FGH2I8446F h4,#LC-FGH2I8446F h5 {margin:0px 0px 4px 0px;    text-align:left;}#LC-FGH2I8446F h3 {margin:1px;text-align:center;}#LC-FGH2I8446F h5 {color:#5D5D5D;font-style:normal;font-weight:normal;}#LC-FGH2I8446F table {color: #3E4349;/*font: normal normal normal 12px/10px "Courier New", monospace!important;*/border-spacing:1px!important;    border-collapse:collapse!important;font-size: 0.9em;font-family:monospace;border-style:solid;border-color:grey;border-width:0px;margin:1px;/*background: #FFF;    table-layout: fixed;*/}#LC-FGH2I8446F table thead,#LC-FGH2I8446F table tbody,#LC-FGH2I8446F table tfoot,#LC-FGH2I8446F table tr {border-color: inherit;border-style:inherit;border-width:0px;}#LC-FGH2I8446F table thead {vertical-align: bottom;border-bottom-width:1px;}#LC-FGH2I8446F table tbody {    display: table-row-group;    vertical-align: middle;overflow:scroll!important;background:transparent!important;}#LC-FGH2I8446F table tfoot {border-top-width:2px;border-top-color:black;}#LC-FGH2I8446F table tr {    vertical-align: middle;    padding: 1px 0.5em;    line-height: normal;    white-space:pre!important;    max-width: none;background:transparent!important;}#LC-FGH2I8446F table th,#LC-FGH2I8446F table td {padding: 1px 0.5em;white-space:pre!important;max-width: none;line-height: normal;min-width:3px;border-width:1px;border-style:inherit;border-color:inherit;vertical-align:middle;font-family: inherit;}#LC-FGH2I8446F table td {text-align: right;}#LC-FGH2I8446F table th:empty,#LC-FGH2I8446F table td:empty {visibility: hidden;}#LC-FGH2I8446F table tbody+tbody:before {content:'...';display:table-row;line-height:10px;text-align:center;}#LC
td></tr>
# </tbody><tfoot><tr><th colspan="1">object</th><td>float</td><td>float</td><td>float</td><td>float</td><td>float</td><td>float</td><td>float</td><td>float</td><td>float</td></tr></tfoot></table></div></section>

# %%
pygraph.scatterplot_matrix(features.drop('Pregnancies',axis=1),show=True)

# %% [markdown]
# # `Preparing Data Set`

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,Imputer

Y_pipeline = Pipeline([
    ('selector', pyml.DataFrameSelector('Outcome'))
])

#feature_names = ['Glucose', 'BMI', 'DiabetesPedigreeFunction', 'Age']
feature_names = ['Glucose','BMI','DPF','BP','Insulin','Age','SkinThck','Pregnancies']

X_pipeline = Pipeline([
    ('selector', pyml.DataFrameSelector(feature_names)),
    #('imputer', Imputer(strategy="median")),
    ('scaler', StandardScaler())
])
X,Y = X_pipeline.fit_transform(diabetes),Y_pipeline.fit_transform(diabetes)
display(X,'X')
display(Y,'Y')
# Out:
# <section id='LC-556Y0PQZPV'><style>#LC-556Y0PQZPV {font-family: monospace;/*font-size:12px;*/max-height:400px!important;overflow:scroll;padding:5px;background:transparent;}#LC-556Y0PQZPV div {border:1px solid transparent!important;background:transparent;margin:5px;}#LC-556Y0PQZPV section {display:flex;flex-flow:row nowrap;align-items:flex-start;justify-content:flex-start;border:0px;padding:0px;}#LC-556Y0PQZPV h3,#LC-556Y0PQZPV h4,#LC-556Y0PQZPV h5 {padding:1px;}#LC-556Y0PQZPV h3,#LC-556Y0PQZPV h4 {font-weight:bold;}#LC-556Y0PQZPV h4,#LC-556Y0PQZPV h5 {margin:0px 0px 4px 0px;    text-align:left;}#LC-556Y0PQZPV h3 {margin:1px;text-align:center;}#LC-556Y0PQZPV h5 {color:#5D5D5D;font-style:normal;font-weight:normal;}#LC-556Y0PQZPV table {color: #3E4349;/*font: normal normal normal 12px/10px "Courier New", monospace!important;*/border-spacing:1px!important;    border-collapse:collapse!important;font-size: 0.9em;font-family:monospace;border-style:solid;border-color:grey;border-width:0px;margin:1px;/*background: #FFF;    table-layout: fixed;*/}#LC-556Y0PQZPV table thead,#LC-556Y0PQZPV table tbody,#LC-556Y0PQZPV table tfoot,#LC-556Y0PQZPV table tr {border-color: inherit;border-style:inherit;border-width:0px;}#LC-556Y0PQZPV table thead {vertical-align: bottom;border-bottom-width:1px;}#LC-556Y0PQZPV table tbody {    display: table-row-group;    vertical-align: middle;overflow:scroll!important;background:transparent!important;}#LC-556Y0PQZPV table tfoot {border-top-width:2px;border-top-color:black;}#LC-556Y0PQZPV table tr {    vertical-align: middle;    padding: 1px 0.5em;    line-height: normal;    white-space:pre!important;    max-width: none;background:transparent!important;}#LC-556Y0PQZPV table th,#LC-556Y0PQZPV table td {padding: 1px 0.5em;white-space:pre!important;max-width: none;line-height: normal;min-width:3px;border-width:1px;border-style:inherit;border-color:inherit;vertical-align:middle;font-family: inherit;}#LC-556Y0PQZPV table td {text-align: right;}#LC-556Y0PQZPV table th:empty,#LC-556Y0PQZPV table td:empty {visibility: hidden;}#LC-556Y0PQZPV table tbody+tbody:before {content:'...';display:table-row;line-height:10px;text-align:center;}#LC-556Y0PQZPV table td.row-sep {visibility:visible;border:none;}#LC-556Y0PQZPV table td.row-sep:before {content:'...';}#LC-556Y0PQZPV table tbody tr,#LC-556Y0PQZPV table tbody tr:hover,#LC-556Y0PQZPV table tbody tr:hover>*{    background: #FFF!important;}#LC-556Y0PQZPV table tr>th:last-of-type {border-right-color:black;}#LC-556Y0PQZPV table th {text-align: right;font-weight: bold;}#LC-556Y0PQZPV table thead th,#LC-556Y0PQZPV table thead td {    text-align: center;    color:#FFF;    text-shadow:1px 1px rgba(0,0,0,1),0px 1px rgba(0,0,0,1),1px 0px rgba(0,0,0,1),-0.5px -0.5px rgba(0,0,0,1);}#LC-556Y0PQZPV table tbody td.grey {background:#EBE8ED;}#LC-556Y0PQZPV table tbody td.light-grey {background:#f3f1f4;}#LC-556Y0PQZPV table tbody th {background:#E1F5FE;}#LC-556Y0PQZPV table thead th {background:#95d1ff;}#LC-556Y0PQZPV table thead td {    background:#33a7ff;}#LC-556Y0PQZPV table tfoot td {    background:#F5F5F5;}#LC-556Y0PQZPV table tfoot th {    background:#d9d9d9;}#LC-556Y0PQZPV table.arrpy tbody th {background:#D8BFD8;}#LC-556Y0PQZ
font-family: monospace;/*font-size:12px;*/max-height:400px!important;overflow:scroll;padding:5px;background:transparent;}#LC-Y3WMORHSC6 div {border:1px solid transparent!important;background:transparent;margin:5px;}#LC-Y3WMORHSC6 section {display:flex;flex-flow:row nowrap;align-items:flex-start;justify-content:flex-start;border:0px;padding:0px;}#LC-Y3WMORHSC6 h3,#LC-Y3WMORHSC6 h4,#LC-Y3WMORHSC6 h5 {padding:1px;}#LC-Y3WMORHSC6 h3,#LC-Y3WMORHSC6 h4 {font-weight:bold;}#LC-Y3WMORHSC6 h4,#LC-Y3WMORHSC6 h5 {margin:0px 0px 4px 0px;    text-align:left;}#LC-Y3WMORHSC6 h3 {margin:1px;text-align:center;}#LC-Y3WMORHSC6 h5 {color:#5D5D5D;font-style:normal;font-weight:normal;}#LC-Y3WMORHSC6 table {color: #3E4349;/*font: normal normal normal 12px/10px "Courier New", monospace!important;*/border-spacing:1px!important;    border-collapse:collapse!important;font-size: 0.9em;font-family:monospace;border-style:solid;border-color:grey;border-width:0px;margin:1px;/*background: #FFF;    table-layout: fixed;*/}#LC-Y3WMORHSC6 table thead,#LC-Y3WMORHSC6 table tbody,#LC-Y3WMORHSC6 table tfoot,#LC-Y3WMORHSC6 table tr {border-color: inherit;border-style:inherit;border-width:0px;}#LC-Y3WMORHSC6 table thead {vertical-align: bottom;border-bottom-width:1px;}#LC-Y3WMORHSC6 table tbody {    display: table-row-group;    vertical-align: middle;overflow:scroll!important;background:transparent!important;}#LC-Y3WMORHSC6 table tfoot {border-top-width:2px;border-top-color:black;}#LC-Y3WMORHSC6 table tr {    vertical-align: middle;    padding: 1px 0.5em;    line-height: normal;    white-space:pre!important;    max-width: none;background:transparent!important;}#LC-Y3WMORHSC6 table th,#LC-Y3WMORHSC6 table td {padding: 1px 0.5em;white-space:pre!important;max-width: none;line-height: normal;min-width:3px;border-width:1px;border-style:inherit;border-color:inherit;vertical-align:middle;font-family: inherit;}#LC-Y3WMORHSC6 table td {text-align: right;}#LC-Y3WMORHSC6 table th:empty,#LC-Y3WMORHSC6 table td:empty {visibility: hidden;}#LC-Y3WMORHSC6 table tbody+tbody:before {content:'...';display:table-row;line-height:10px;text-align:center;}#LC-Y3WMORHSC6 table td.row-sep {visibility:visible;border:none;}#LC-Y3WMORHSC6 table td.row-sep:before {content:'...';}#LC-Y3WMORHSC6 table tbody tr,#LC-Y3WMORHSC6 table tbody tr:hover,#LC-Y3WMORHSC6 table tbody tr:hover>*{    background: #FFF!important;}#LC-Y3WMORHSC6 table tr>th:last-of-type {border-right-color:black;}#LC-Y3WMORHSC6 table th {text-align: right;font-weight: bold;}#LC-Y3WMORHSC6 table thead th,#LC-Y3WMORHSC6 table thead td {    text-align: center;    color:#FFF;    text-shadow:1px 1px rgba(0,0,0,1),0px 1px rgba(0,0,0,1),1px 0px rgba(0,0,0,1),-0.5px -0.5px rgba(0,0,0,1);}#LC-Y3WMORHSC6 table tbody td.grey {background:#EBE8ED;}#LC-Y3WMORHSC6 table tbody td.light-grey {background:#f3f1f4;}#LC-Y3WMORHSC6 table tbody th {background:#E1F5FE;}#LC-Y3WMORHSC6 table thead th {background:#95d1ff;}#LC-Y3WMORHSC6 table thead td {    background:#33a7ff;}#LC-Y3WMORHSC6 table tfoot td {    background:#F5F5F5;}#LC-Y3WMORHSC6 table tfoot th {    background:#d9d9d9;}#LC-Y3WMORHSC6 table.arrpy tbody th {background:#D8BFD8;}#LC-Y3WMORHSC6 table.arrpy thead th {background:#EE82EE;}#LC-Y3WMORHSC6 table.arrpy thead td {    background:#DA70D6;}#LC-Y3WMORHSC6 table.pandas tbody th {background:#E1F5FE;}#LC-Y3WMORHSC6 table.pandas thead th {background:#95d1ff;}#LC-Y3WMORHSC6 table.pandas thead td {    background:#33a7ff;}#LC-Y3WMORHSC6 table.numpy tbody th {background:#EEEEFE;}#LC-Y3WMORHSC6 table.numpy tr>th:last-of-type {border-right-color:grey;margin-right:3px;}</style><div><h4>Y</h4><h5>array[768]</h5><table class='numpy array-1d'><tbody><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td class='row-sep'></td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td></tr></tbody></table></div></section>

# %% [markdown]
# # `Model Selection`
#
# * `DecisionTreeClassifier (sklearn.tree)`
# * `KNeighborsClassifier (sklearn.neighbors)`
#
# ### `Links`
# - [`Decision Tree`](https://www.garysieling.com/blog/sklearn-gini-vs-entropy-criteria)
# - [`k-nearest-neighbors`](https://kevinzakka.github.io/2016/07/13/k-nearest-neighbor/)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC,NuSVC,LinearSVC
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier

MODEL = [('kNN', KNeighborsClassifier,{}),
          ('SVC', SVC,{'kernel':'rbf','decision_function_shape':'ovo'}),
          ('NuSVC', NuSVC,{'kernel':'rbf','decision_function_shape':'ovo'}),
          ('LinearSVC', LinearSVC,{}),
          ('Logistic Regression', LogisticRegression,{}),
          ('Decision Tree', DecisionTreeClassifier,{}),
          ('GaussianNB', GaussianNB,{}),
          ('Random Forest', RandomForestClassifier,{}),
          ('Gradient Boosting', GradientBoostingClassifier,{})]

# %% [markdown]
# ## `Test Models with Cross Validation`

# %%
from sklearn.model_selection import cross_val_score,KFold,StratifiedKFold
from sklearn.metrics import accuracy_score
kfold = KFold(n_splits=10, random_state=10)
strat_kfold = StratifiedKFold(n_splits=10, random_state=11)

@pydec.pd_series('Model','Accuracy')
def run_tests(models,X,Y):
    for key,cls,args in models:
        score = cross_val_score(cls(**args),X,Y,cv=strat_kfold,scoring='accuracy').mean()
        yield key,score

# %%
display(run_tests(MODEL,X,Y),'Various Model Accuracy Scores')
# Out:
# <section id='LC-EAW09ETSYT'><style>#LC-EAW09ETSYT {font-family: monospace;/*font-size:12px;*/max-height:400px!important;overflow:scroll;padding:5px;background:transparent;}#LC-EAW09ETSYT div {border:1px solid transparent!important;background:transparent;margin:5px;}#LC-EAW09ETSYT section {display:flex;flex-flow:row nowrap;align-items:flex-start;justify-content:flex-start;border:0px;padding:0px;}#LC-EAW09ETSYT h3,#LC-EAW09ETSYT h4,#LC-EAW09ETSYT h5 {padding:1px;}#LC-EAW09ETSYT h3,#LC-EAW09ETSYT h4 {font-weight:bold;}#LC-EAW09ETSYT h4,#LC-EAW09ETSYT h5 {margin:0px 0px 4px 0px;    text-align:left;}#LC-EAW09ETSYT h3 {margin:1px;text-align:center;}#LC-EAW09ETSYT h5 {color:#5D5D5D;font-style:normal;font-weight:normal;}#LC-EAW09ETSYT table {color: #3E4349;/*font: normal normal normal 12px/10px "Courier New", monospace!important;*/border-spacing:1px!important;    border-collapse:collapse!important;font-size: 0.9em;font-family:monospace;border-style:solid;border-color:grey;border-width:0px;margin:1px;/*background: #FFF;    table-layout: fixed;*/}#LC-EAW09ETSYT table thead,#LC-EAW09ETSYT table tbody,#LC-EAW09ETSYT table tfoot,#LC-EAW09ETSYT table tr {border-color: inherit;border-style:inherit;border-width:0px;}#LC-EAW09ETSYT table thead {vertical-align: bottom;border-bottom-width:1px;}#LC-EAW09ETSYT table tbody {    display: table-row-group;    vertical-align: middle;overflow:scroll!important;background:transparent!important;}#LC-EAW09ETSYT table tfoot {border-top-width:2px;border-top-color:black;}#LC-EAW09ETSYT table tr {    vertical-align: middle;    padding: 1px 0.5em;    line-height: normal;    white-space:pre!important;    max-width: none;background:transparent!important;}#LC-EAW09ETSYT table th,#LC-EAW09ETSYT table td {padding: 1px 0.5em;white-space:pre!important;max-width: none;line-height: normal;min-width:3px;border-width:1px;border-style:inherit;border-color:inherit;vertical-align:middle;font-family: inherit;}#LC-EAW09ETSYT table td {text-align: right;}#LC-EAW09ETSYT table th:empty,#LC-EAW09ETSYT table td:empty {visibility: hidden;}#LC-EAW09ETSYT table tbody+tbody:before {content:'...';display:table-row;line-height:10px;text-align:center;}#LC-EAW09ETSYT table td.row-sep {visibility:visible;border:none;}#LC-EAW09ETSYT table td.row-sep:before {content:'...';}#LC-EAW09ETSYT table tbody tr,#LC-EAW09ETSYT table tbody tr:hover,#LC-EAW09ETSYT table tbody tr:hover>*{    background: #FFF!important;}#LC-EAW09ETSYT table tr>th:last-of-type {border-right-color:black;}#LC-EAW09ETSYT table th {text-align: right;font-weight: bold;}#LC-EAW09ETSYT table thead th,#LC-EAW09ETSYT table thead td {    text-align: center;    color:#FFF;    text-shadow:1px 1px rgba(0,0,0,1),0px 1px rgba(0,0,0,1),1px 0px rgba(0,0,0,1),-0.5px -0.5px rgba(0,0,0,1);}#LC-EAW09ETSYT table tbody td.grey {background:#EBE8ED;}#LC-EAW09ETSYT table tbody td.light-grey {background:#f3f1f4;}#LC-EAW09ETSYT table tbody th {background:#E1F5FE;}#LC-EAW09ETSYT table thead th {background:#95d1ff;}#LC-EAW09ETSYT table thead td {    background:#33a7ff;}#LC-EAW09ETSYT table tfoot td {    background:#F5F5F5;}#LC-EAW09ETSYT table tfoot th {    background:#d9d9d9;}#LC-EAW09ETSYT table.arrpy tbody th {background:#D8BFD8;}#LC-EAW09ETSYT table.arrpy thead th {background:#EE82EE;}#LC-EAW09ETSYT table.arrpy thead td {    background:#DA70D6;}#LC-EAW09ETSYT table.pandas tbody th {background:#E1F5FE;}#LC-EAW09ETSYT table.pandas thead th {background:#95d1ff;}#LC-EAW09ETSYT table.pandas thead td {    background:#33a7ff;}#LC-EAW09ETSYT table.numpy tbody th {background:#EEEEFE;}#LC-EAW09ETSYT table.numpy tr>th:last-of-type {border-right-color:grey;margin-right:3px;}</style><div><h4>Various Model Accuracy Scores</h4><h5>Series[9]</h5><table class='pandas series'><thead><tr><th>Model</th><th>Accuracy</th></tr>
# </thead><tbody><tr><th>kNN</th><td>0.738</td></tr>
# <tr><th>SVC</th><td>0.762</td></tr>
# <tr><th>NuSVC</th><td>0.759</td></tr>
# <tr><th>LinearSVC</th><td>0.773</td></tr>
# <tr><th>Logistic Regression</th><td>0.771</td></tr>
# <tr><th>Decision Tree</th><td>0.711</td></tr>
# <tr><th>GaussianNB</th><td>0.756</td></tr>
# <tr><th>Random Forest</th><td>0.746</td></tr>
# <tr><th>Gradient Boosting</th><td>0.762</td></tr>
# </tbody><tfoot><tr><th colspan="1">object</th><td>float</td></tr></tfoot></table></div></section>

# %% [markdown]
# # `Facet Grid`

# %%
sns.FacetGrid(diabetes,hue="Outcome").map(plt.scatter, "BP", "BMI").add_legend()
plt.show()

# %%
pygraph.scatterplot_matrix(diabetes,facet_hue='Outcome',show=True)
